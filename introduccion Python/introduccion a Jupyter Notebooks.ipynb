# %% [markdown]
# # Introduccion a Jupyter Notebooks

# %% [markdown]
# # Título nivel 1
# ## Título nivel 2
# ### Título nivel 3
# ### Título nivel 4
# #### Título nivel 5
# ##### Título nivel 6

# %% [markdown]
# *Texto en cursiva*<br>
# **Texto en negrita**<br>
# ***Texto en negrita y cursiva***<br>
# *Este texto está en cursiva y **negrita** al mismo tiempo*<br>

# %% [markdown]
# - elemento 1 listas desordenada
# - elemento 2 listas desordenada
#
# <br>
#
# 1. elemento 1 listas ordenada
# 1. elemento 2 listas ordenada
#
# <br>
#
# 7. esta lista ordenada empieza en 7
# 7. esta lista ordenada empieza en 7
#
# <br>
#
# - elemento 1 listas desordenada nivel 1
#     1. elemento 1 listas ordenada nivel 2
#         - elemento 1 listas desordenada nivel 3
#     2. elemento 2 listas ordenada nivel 2
# - elemento 2 listas desordenada nivel 1
